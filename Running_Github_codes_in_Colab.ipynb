# %% [markdown]
# <a href="https://colab.research.google.com/github/egg-seed/python-decorator-tutorial/blob/main/Running_Github_codes_in_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Running Github codes in Google Colab

# %%
#Githubよりリポジトリをcloneする
# !git clone https://github.com/egg-seed/python-decorator-tutorial.git
# Out:
# Cloning into 'python-decorator-tutorial'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 41 (delta 3), reused 35 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (41/41), 49.10 KiB | 4.09 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %% [markdown]
# #作業ディレクトリを移動

# %%
#作業ディレクトリ直下のファイルを確認
# %cd python-decorator-tutorial
# %pip install -q uv
# !uv sync

# !ls
# Out:
# /content/python-decorator-tutorial
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.5 MB/s eta 0:00:00
# Using CPython 3.14.3
# Creating virtual environment at: .venv
# Resolved 15 packages in 1ms
# ⠙ Preparing packages... (0/14)                                                  warning: `build_system.requires = ["uv-build>=0.10.7,<0.11.0"]` does not contain the
#                         current uv version 0.11.2
# Prepared 14 packages in 1.02s
# Installed 14 packages in 67ms
#  + coverage==7.13.5
#  + iniconfig==2.3.0
#  + librt==0.8.1
#  + mypy==1.19.1
#  + mypy-extensions==1.1.0
#  + packaging==26.0
#  + pathspec==1.0.4
#  + pluggy==1.6.0
#  + pygments==2.19.2
#  + pytest==9.0.2
#  + pytest-cov==7.1.0
#  + python-decorator-tutorial==0.1.0 (from file:///content/python-decorator-tutorial)
#  + ruff==0.15.7
#  + typing-extensions==4.15.0
# pyproject.toml	README.md			     src    uv.lock
# README.en.md	Running_Github_codes_in_Colab.ipynb  tests

# %% [markdown]
# # 01: デコレータがないと何が困るか（DRY違反の問題提起）

# %%
# !uv run python src/decorator_tutorial/01_problem_without_decorator.py
# Out:
# ==================================================
# デコレータなし: ログ処理を手動でコピペ
# ==================================================
# [開始] add を呼び出します (引数: a=3, b=5)
# [完了] add が終わりました (戻り値: 8)
#   → 結果: 8
#
# [開始] multiply を呼び出します (引数: a=4, b=7)
# [完了] multiply が終わりました (戻り値: 28)
#   → 結果: 28
#
# [開始] greet を呼び出します (引数: name='太郎')
# [完了] greet が終わりました (戻り値: 'こんにちは、太郎さん！')
#   → 結果: 'こんにちは、太郎さん！'
#
# ==================================================
# 【問題点まとめ】
#   ・ログ処理が 3 箇所にコピペされている
#   ・ログのフォーマットを変えたい場合、3 箇所すべてを修正する必要がある
#   ・関数が 100 個あれば 100 箇所を修正することになる → DRY 原則違反！
#   ・次のファイル (02_basic_decorator.py) でデコレータによる解決策を学ぼう
# ==================================================

# %% [markdown]
# #02: 基本的なデコレータ

# %%
# !uv run python src/decorator_tutorial/02_basic_decorator.py
# Out:
# =======================================================
# デコレータあり: ログ処理を一箇所に集約
# =======================================================
# [開始] add を呼び出します (引数: (3, 5), {})
# [完了] add が終わりました (戻り値: 8)
#   → 結果: 8
#
# [開始] multiply を呼び出します (引数: (4, 7), {})
# [完了] multiply が終わりました (戻り値: 28)
#   → 結果: 28
#
# [開始] greet を呼び出します (引数: ('太郎',), {})
# [完了] greet が終わりました (戻り値: 'こんにちは、太郎さん！')
#   → 結果: 'こんにちは、太郎さん！'
#
# [開始] subtract を呼び出します (引数: (10, 3), {})
# [完了] subtract が終わりました (戻り値: 7)
#   → 結果: 7
#
# =======================================================
# 【ポイント】
#   ・ログ処理は log_decorator の中に 1 箇所だけ書いた
#   ・フォーマットを変えたい場合は log_decorator を修正するだけ！
#   ・01 の DRY 違反が解消された
# =======================================================

# %% [markdown]
# # 03: 引数を取るデコレータ（デコレータファクトリ）

# %%
# !uv run python src/decorator_tutorial/03_decorator_with_args.py
# Out:
# =======================================================
# 引数付きデコレータ（デコレータファクトリ）
# =======================================================
#
# --- @repeat(times=3) ---
#   (1/3回目)
#     こんにちは！
#   (2/3回目)
#     こんにちは！
#   (3/3回目)
#     こんにちは！
#
# --- @log_with_level(level='DEBUG') ---
# [DEBUG] fetch_data 開始
# [DEBUG] fetch_data 完了 (0.0000秒)
#   取得結果: 'https://example.com/api のデータ'
#
# --- @log_with_level(level='WARNING') ---
# [WARNING] delete_user 開始
# [WARNING] delete_user 完了 (0.0000秒)
#   削除結果: True
#
# =======================================================
# 【3重ネスト構造まとめ】
#   1層目 (ファクトリ): repeat(times=3) ← 引数を受け取る
#   2層目 (デコレータ): decorator(func)  ← 関数を受け取る
#   3層目 (ラッパー):   wrapper(*args)   ← 実際に呼ばれる
# =======================================================

# %% [markdown]
# # 04: functools.wraps でメタデータを保持する

# %%
# !uv run python src/decorator_tutorial/04_functools_wraps.py
# Out:
# =======================================================
# functools.wraps によるメタデータ保持
# =======================================================
#
# --- @wraps なし (悪い例) ---
#   __name__     : wrapper
#   __qualname__ : log_without_wraps.<locals>.wrapper
#   __doc__      : None
#   __module__   : __main__
#
# --- @wraps あり (良い例) ---
#   __name__     : add_good
#   __qualname__ : add_good
#   __doc__      : '2つの整数を足し算する（wraps あり版）。'
#   __module__   : __main__
#
# --- 実行結果の比較 ---
# [LOG] 呼び出し中...
#   add_bad(3, 5)  = 8
# [LOG] 呼び出し中...
#   add_good(3, 5) = 8
#
# =======================================================
# 【ルール】デコレータを書くときは必ず @functools.wraps(func) を付ける
#   理由: ログ・デバッグ・テスト・IDE の補完で正しい情報が見えるようになる
# =======================================================

# %% [markdown]
# # 05: Python 組み込みデコレータ 4 選

# %%
# !uv run python src/decorator_tutorial/05_builtin_decorators.py
# Out:
# =======================================================
# Python 組み込みデコレータ 4 選
# =======================================================
#
# --- @property: Temperature クラス ---
#   摂氏: 100.0℃  華氏: 212.0°F
#   摂氏: 0.0℃  華氏: 32.0°F
#   エラー: 絶対零度 (-273.15℃) 未満は設定できません: -300.0
#   温度をリセットします
#   リセット後: 0.0℃
#
# --- @classmethod: User ファクトリ ---
#   辞書から作成: User(name='田中太郎', email='taro@example.com', age=30)
#   JSON から作成: User(name='山田花子', email='hanako@example.com', age=25)
#
# --- @staticmethod: EmailValidator ---
#   'Taro@Example.COM '            → 正規化: 'taro@example.com'        有効: True
#   'invalid-email'                → 正規化: 'invalid-email'           有効: False
#   'hanako@test.co.jp'            → 正規化: 'hanako@test.co.jp'       有効: True
#
# --- @lru_cache: フィボナッチ数列 ---
#   fibonacci(10) =         55  キャッシュ統計: CacheInfo(hits=8, misses=11, maxsize=128, currsize=11)
#   fibonacci(20) =       6765  キャッシュ統計: CacheInfo(hits=19, misses=21, maxsize=128, currsize=21)
#   fibonacci(30) =     832040  キャッシュ統計: CacheInfo(hits=30, misses=31, maxsize=128, currsize=31)
#   fibonacci(35) =    9227465  キャッシュ統計: CacheInfo(hits=36, misses=36, maxsize=128, currsize=36)
#
# =======================================================
# 【各デコレータの使いどころ】
#   @property    : 内部実装を隠しつつ属性らしいインターフェースを提供
#   @classmethod : 複数の入力形式に対応したファクトリメソッド
#   @staticmethod: クラスに論理的に属するが状態不要なユーティリティ
#   @lru_cache   : 高コスト計算・再帰関数のパフォーマンス改善
# =======================================================

# %% [markdown]
# # 06: クラスベースのデコレータ
#
# **このファイルで学ぶこと**:
# - `__call__` を持つクラスをデコレータとして使う方法
# - クラスデコレータのメリット: 状態（呼び出し回数など）を保持できる
# - Protocol を使ったデコレータの型制約

# %%
# !uv run python src/decorator_tutorial/06_class_decorator.py
# Out:
# =======================================================
# クラスベースのデコレータ
# =======================================================
#
# --- CallCounter: 呼び出し回数を記録 ---
#   現在のカウント: 0
# [カウンター] process の呼び出し回数: 1回目
# [カウンター] process の呼び出し回数: 2回目
# [カウンター] process の呼び出し回数: 3回目
#   合計呼び出し回数: 3
#   リセット後: 0
#
# --- Retry: 自動リトライ ---
#   [リトライ] unstable_operation: 1/3 回目 失敗 (接続に失敗しました（ダミーエラー）)
#   [リトライ] unstable_operation: 2/3 回目 失敗 (接続に失敗しました（ダミーエラー）)
#   結果: '操作成功！'
#
# =======================================================
# 【クラスデコレータのメリット】
#   ・インスタンス変数で状態を管理できる（関数デコレータには難しい）
#   ・__init__ に設定値を持たせてデコレータとしても設定値保持用としても使える
#   ・reset() のような追加メソッドを定義できる
# =======================================================

# %% [markdown]
# # 07: ParamSpec と TypeVar で型安全なデコレータを書く。
#
# **このファイルで学ぶこと**:
# - `Callable[..., Any]` の問題点（型情報が失われる）
# - `ParamSpec`: 関数の引数シグネチャを型変数として表現する
# - `TypeVar`: 戻り値の型を保持する
# - `mypy` が strict モードでデコレータを正しく解析できるようになる

# %%
# !uv run python src/decorator_tutorial/07_paramspec_basics.py
# Out:
# =======================================================
# ParamSpec + TypeVar による型安全なデコレータ
# =======================================================
#
# --- Callable[..., Any] 版（型情報なし）---
# [LOG] add_untyped 呼び出し
#   add_untyped(3, 5) = 8
#
# --- ParamSpec + TypeVar 版（型安全）---
# [LOG] add_typed 呼び出し
#   add_typed(3, 5) = 8
#
# --- @timer（型安全な実用デコレータ）---
# [TIMER] slow_sum: 0.037224秒
#   合計: 499999500000
#
# =======================================================
# 【ParamSpec のポイント】
#   P = ParamSpec('P')  → 引数シグネチャを型変数として保持
#   T = TypeVar('T')    → 戻り値型を型変数として保持
#   Callable[P, T]      → 元の関数と同じ型シグネチャのデコレータ
#   *args: P.args       → P の位置引数
#   **kwargs: P.kwargs  → P のキーワード引数
# =======================================================

# %% [markdown]
# # 08: Concatenate で引数を追加・変換するデコレータ。
#
# **このファイルで学ぶこと**:
# - `Concatenate`: 既存の引数シグネチャに引数を「追加」する型ツール
# - `ParamSpec` だけでは表現できない「引数を注入するデコレータ」のパターン
# - 典型的なユースケース: 認証トークン・リクエストオブジェクトの注入

# %%
# !uv run python src/decorator_tutorial/08_generic_decorator.py
# Out:
# =======================================================
# Concatenate: 引数を自動注入するデコレータ
# =======================================================
#
# --- @inject_user_id: user_id を自動注入 ---
#   [認証] ユーザー ID を注入: 'user-001'
#   プロフィール: {'user_id': 'user-001', 'name': 'テストユーザー', 'email': 'test@example.com'}
#
# --- @inject_logger: logger を自動注入 ---
#   [process_order] INFO: 注文 #42 の処理開始 (金額: 9800.0円)
#   [process_order] INFO: 注文 #42 完了
#   結果: '注文 #42 完了'
#
# =======================================================
# 【Concatenate の読み方】
#   Callable[Concatenate[str, P], T]
#     → 「str を先頭に持ち、残りが P の引数シグネチャで、T を返す」関数
#   注入されるものの例: user_id, logger, db_session, request など
# =======================================================

# %% [markdown]
# # 09: 引数あり / なし両対応のデコレータファクトリ（最終形）。
#
# このファイルで学ぶこと:
# - @overload: 引数ありと引数なし両対応の型定義
# - 引数なし (@deco) でも引数あり (@deco(n=3)) でも使えるデコレータ
# - 実務でよく見るフレームワーク API スタイルの実装

# %%
# !uv run python src/decorator_tutorial/09_decorator_factory.py
# Out:
# =======================================================
# 引数あり/なし両対応 デコレータファクトリ
# =======================================================
#
# --- @retry（引数なし）: max_attempts=3 ---
#   [RETRY] unstable_no_args: 1/3 回目 失敗 (ダミーエラー（引数なし版）)
#   [RETRY] unstable_no_args: 2/3 回目 失敗 (ダミーエラー（引数なし版）)
#   結果: '成功（引数なし版）'
#
# --- @retry(max_attempts=5)（引数あり）---
#   [RETRY] unstable_with_args: 1/5 回目 失敗 (ダミー接続エラー（引数あり版）)
#   [RETRY] unstable_with_args: 2/5 回目 失敗 (ダミー接続エラー（引数あり版）)
#   [RETRY] unstable_with_args: 3/5 回目 失敗 (ダミー接続エラー（引数あり版）)
#   結果: '成功（引数あり版）'
#
# =======================================================
# 【@overload パターンのポイント】
#   ・@overload で型シグネチャを 2 パターン宣言
#   ・実装本体は func=None で両方を受け取れるようにする
#   ・func is not None のとき → 引数なし (@deco)
#   ・func is None のとき     → 引数あり (@deco(...))
# =======================================================

# %% [markdown]
# # 10: デコレータの積み重ね（スタック）。
#
# **このファイルで学ぶこと**:
# - 複数のデコレータを重ねたときの適用順序
# - 「内側から外側へ」適用され「外側から内側へ」実行される
# - 型の伝播: 各デコレータが型を正しく通過させるとスタックしても型安全

# %%
# !uv run python src/decorator_tutorial/10_stacking_decorators.py
# Out:
# =======================================================
# デコレータのスタック順序
# =======================================================
#
# --- @log @timer @validate_positive ---
#   (実行順: log → timer → validate → 関数本体)
#   [LOG  ] compute 開始
#   [VALID] compute: 引数 7 は有効
#   [TIMER] compute: 0.000008秒
#   [LOG  ] compute 完了
#   compute(7) = 49
#
# --- エラーの場合（log と timer が先に実行される）---
#   [LOG  ] compute 開始
#   ValueError: 第 1 引数は正の整数である必要があります: -1
#
# --- @validate_positive @log @timer ---
#   (実行順: validate → log → timer → 関数本体)
#   [VALID] compute_v2: 引数 5 は有効
#   [LOG  ] compute_v2 開始
#   [TIMER] compute_v2: 0.000001秒
#   [LOG  ] compute_v2 完了
#   compute_v2(5) = 25
#
# --- エラーの場合（validate が最初に実行されて即エラー）---
#   ValueError: 第 1 引数は正の整数である必要があります: -1
#
# =======================================================
# 【スタック順序のまとめ】
#   @A        適用: C → B → A（内から外）
#   @B        実行: A → B → C → 本体 → C → B → A
#   @C
#   def func(): ...
#
#   ポイント: バリデーションは外側（最後に書く）に置くと
#             無駄な処理（ログ・タイマー）が実行される前にエラーを弾ける
# =======================================================
